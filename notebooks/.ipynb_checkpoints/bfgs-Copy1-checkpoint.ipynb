# %%
import jax
from typing import Any, Callable, Sequence, Optional
from jax import lax, random, numpy as jnp
import flax
from flax import linen as nn
import sympy as sy
import numpy as np
import sys
sys.path.append("../")

from eql.eqlearner import EQL
import eql.custom_functions as custom_functions
from eql.symbolic import get_symbolic_expr, get_symbolic_expr_layer
from typing import List, Tuple, Callable
from functools import partial
import matplotlib.pyplot as plt
import cma

# %%
import scipy
sys.path.append("../../orient")
from eql.np_utils import flatten, unflatten

# %%
#funs = ['sin', 'cos', 'id', 'mul']
funs = ['mul', 'cos', 'sin', 'square']
e = EQL(n_layers=1, functions=funs, features=1, use_l0=False, drop_rate=0.8, temperature=2./3)

# %%
key = random.PRNGKey(3)
key, k1, k2 = random.split(key, 3)

# %%
N = 10000
xdim = 2
x = (random.uniform(key, (N, xdim))-.5) *2 
#x = np.array([[1., 2.]]).T
#x = np.linspace(-1, 1, N)[:,None]
y = x[:,0] + jnp.cos(x[:,1])
#y = jnp.cos(x) + 1 - x**2 

#y = jnp.cos(x) + 1 - x**2 - jnp.sin(4*x)


def make_l0_func():
    def l0(params, key):
        return e.apply(params, rngs={'l0':key}, method=e.l0_reg)
    return jax.jit(l0)


def my_mse(params, key):
    #pred = e.apply(params, x)
    pred = e.apply(params, x, rngs={'l0': key})
    return jnp.mean((pred-y)**2)


def my_mse(params, key):
    def err(x,y):
        pred = e.apply(params, x, rngs={'l0': key})
        return (pred-y)**2
    return jnp.mean(jax.vmap(err)(x,y))


mse_fn = jax.jit(my_mse)#make_mse_func(x, y)
l0_fn = make_l0_func()

params = e.init({'params':k1, 'l0': k2}, x);

# %%
def fex(params, key):
    return jnp.reshape(e.apply(params,  x, rngs={'l0': key}), (1, 1000))

# %%
#jax.grad(fex)(params, key)

# %%
def loss(params, key):
#     a =  mse_fn(params, key)
#     b = 1e-3*l0_fn(params, key)
#     print(a, b)
#     return a+b
    return mse_fn(params, key)# + 1e-2*l0_fn(params, key)
loss_grad_fn = jax.jit(jax.value_and_grad(loss))
loss = jax.jit(loss)

# %%
spec, flat = flatten(params)

# %%
def np_fn(params, key):
    params = unflatten(spec, params)
    
    key = jax.random.fold_in(key, np_fn.counter)
    loss, grad = loss_grad_fn(params, key)
    _, grad = flatten(grad)
    
    #print(loss)
    np_fn.counter += 1

    return loss, np.array(grad)
np_fn.counter = 0

# %%
def np_fn2(params):
    params = unflatten(spec, params)
    np_fn2.key, _ = random.split(np_fn2.key)
    print(mse_fn(params, np_fn2.key), 1e-3*l0_fn(params, np_fn2.key))
    return float(loss(params, np_fn2.key))
np_fn2.key = key

# %%
opts = {'maxiter':100, 'verbose': -0}
#opts = {'verbose': -9}

res = cma.fmin(np_fn, flat, 1.0, restarts=10, options=opts)
#res = cma.fmin(np_fn2, np.zeros_like(flat), 1.0, restarts=0, options=opts)
# Out:
# (6_w,12)-aCMA-ES (mu_w=3.7,w_1=40%) in dimension 20 (seed=160373, Sun Jan  5 19:12:36 2025)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 opts = {'maxiter':100, 'verbose': -0}
#       2 #opts = {'verbose': -9}
# ----> 4 res = cma.fmin(np_fn, flat, 1.0, restarts=10, options=opts)
#       5 #res = cma.fmin(np_fn2, np.zeros_like(flat), 1.0, restarts=0, options=opts)
#
# File c:\Users\Simon\.conda\envs\EQL\Lib\site-packages\cma\evolution_strategy.py:4176, in fmin(objective_function, x0, sigma0, options, args, gradf, restarts, restart_from_best, incpopsize, eval_initial_x, parallel_objective, noise_handler, noise_change_sigma_exponent, noise_kappa_exponent, bipop, callback, init_callback)
#    4173 if 1 < 3:
#    4174     while not es.stop():  # iteration loop
#    4175         # X, fit = eval_in_parallel(lambda: es.ask(1)[0], es.popsize, args, repetitions=noisehandler.evaluations-1)
# -> 4176         X, fit = es.ask_and_eval(parallel_objective or objective_function,
#    4177                                  args, gradf=gradf,
#    4178                                  evaluations=noisehandler.evaluations,
#    4179                                  aggregation=np.median,
#    4180                                  parallel_mode=parallel_objective)  # treats NaN with resampling if not parallel_mode
#    4181         # TODO: check args and in case use args=(noisehandler.evaluations, )
#    4183         if 11 < 3 and opts['vv']:  # inject a solution
#    4184             # use option check_point = [0]
#
# File c:\Users\Simon\.conda\envs\EQL\Lib\site-packages\cma\evolution_strategy.py:1893, in CMAEvolutionStrategy.ask_and_eval(self, func, args, gradf, number, xmean, sigma_fac, evaluations, aggregation, kappa, parallel_mode)
#    1889     length_normalizer = self.N**0.5 / self.mahalanobis_norm(x - xmean)  # self.const.chiN < N**0.5, the constant here is irrelevant (absorbed by kappa)
#    1890     # print(self.N**0.5 / self.mahalanobis_norm(x - xmean))
#    1891     # self.more_to_write += [length_normalizer * 1e-3, length_normalizer * self.mahalanobis_norm(x - xmean) * 1e2]
# -> 1893 f = func(x, *args) if kappa == 1 else \
#    1894     func(xmean + kappa * length_normalizer * (x - xmean),
#    1895          *args)
#    1896 if is_feasible(x, f) and evaluations > 1:
#    1897     f = aggregation([f] + [(func(x, *args) if kappa == 1 else
#    1898                             func(xmean + kappa * length_normalizer * (x - xmean), *args))
#    1899                            for _i in range(int(evaluations - 1))])
#
# TypeError: np_fn() missing 1 required positional argument: 'key'

# %%
symb = get_symbolic_expr(unflatten(spec,res[0]), funs, use_l0=True)
#symb = get_symbolic_expr(unflatten(spec,flat), funs, use_l0=True)

sy.simplify(symb[0])
# Out:
# -1.13915958607632*x0**2 + 1.29728726131245*x0 + 3.27070770834984*sin(0.000184485252248123*x0 + 0.039096899330616*x1 - 0.538698572374703) + 1.79700277605529*cos(0.598681092262268*x0 + 1.12281775474548*x1 + 0.19338450865841) + 1.67500466655086

# %%
for i in range(5000):
    key, _ = random.split(key)
    x0, _, info = scipy.optimize.fmin_l_bfgs_b(
            np_fn,
            args=[key],
            x0 = np.array(flat),
            maxfun=4,
            factr=1,
            m=20,
            pgtol=1e-14)
    print(mse_fn(unflatten(spec, flat), key))
    print(l0_fn(unflatten(spec, flat), key))
    flat = x0
# Out:
# 1.0142808
# 7.742767
# 0.025669143
# 8.017872
# 0.0636909
# 8.013855
# 0.35226044
# 7.9439554
# 1.0766695
# 7.9439135
# 0.13997754
# 7.926749
# 0.43441015
#         np_fn,
#         args=[key],
#         x0 = np.array(flat),
#         maxfun=10,
#         factr=1,
#         m=30,
#         pgtol=1e-12)
#     if i % 99 == 0:
#         print(mse_fn(unflatten(spec,x0), key))
#         #print(l0_fn(unflatten(spec,x0), key))
#     flat = x0

# %%
#symb = get_symbolic_expr(unflatten(spec, x0), funs)[0]
symb = get_symbolic_expr(unflatten(spec,flat), funs, use_l0=True)
#outs = sy.lambdify("x0", symb[0])(x[:,0])#, x[:,1], x[:,2])
outs = sy.lambdify("x0, x1", symb)(x[:,0], x[:,1])#, x[:,2])

# %%
sy.simplify(symb[0])
# Out:
# 9.88942382574524e-5*x0**2 - 0.000205627072665137*x0*x1 + 0.0602840281131538*x0 - 0.462924490204906*x1**2 + 0.000481848860362249*x1 + 1.5674093672516*sin(0.630731880664825*x0 - 2.72462402790552e-5*x1 + 0.00855756057481335) + 0.0300864069526525*cos(0.0342039577662945*x0 + 0.000697843148373067*x1 - 1.541588896485) + 0.986982676193658

# %%
plt.scatter(x,y)
#plt.scatter(x,e.apply(unflatten(spec, x0), x),alpha=.3,marker='.')
plt.scatter(x,outs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3003662/802791474.py in <module>
# ----> 1 plt.scatter(x,y)
#       2 #plt.scatter(x,e.apply(unflatten(spec, x0), x),alpha=.3,marker='.')
#       3 plt.scatter(x,outs)
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3066         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3067         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3068     __ret = gca().scatter(
#    3069         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4496         y = np.ma.ravel(y)
#    4497         if x.size != y.size:
# -> 4498             raise ValueError("x and y must be the same size")
#    4499
#    4500         if s is None:
#
# ValueError: x and y must be the same size

# %%
import optax
tx = optax.adam(learning_rate=1e-1)
opt_state = tx.init(params)
loss_grad_fn = jax.jit(jax.value_and_grad(loss))

# %%
for i in range(4000):
    key, k1 = random.split(key)
    loss_val, grads = loss_grad_fn(params, key)
    updates, opt_state = tx.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    if i % 99 == 0:
        print(loss_val)
        print(mse_fn(params, key))
        print(l0_fn(params, key))
# Out:
# 0.0010739606
# 0.06106488
# 8.0400505
# 0.0017892709
# 0.0014302284
# 7.311308
# 0.0027507562
# 0.002840956
# 6.5728893
# 0.0007634655
# 0.00017455933
# 5.8760805
# 0.00068539585
# 0.00015522007
# 5.568014
# 0.000790686
# 0.0005522137
# 5.35978
# 0.0006297891
# 0.00010656484
# 5.22776
# 0.00063819555
# 0.00023558241
# 5.1143894
# 0.0005793412
# 8.819922e-05
# 4.9069724
# 0.0005112107
# 7.1118164e-05
# 4.3954396
# 0.0011749963
# 0.00021186448
# 4.2005644
# 0.0005964706
# 0.00012834634
# 4.1414623
# 0.0005026829
# 9.0596026e-05
# 4.1110926
# 0.0008562432
# 0.0008147819
# 4.091173
# 0.00054074934
# 0.00013241661
# 4.077195
# 0.0005006429
# 9.3721865e-05
# 4.066473
# 0.00048010526
# 7.413845e-05
# 4.0579534
# 0.0004673293
# 6.212271e-05
# 4.0510178
# 0.00081004534
# 0.00037283028
# 4.045266
# 0.0037998946
# 0.0040285434
# 4.040435
# 0.010536808
# 0.0011304617
# 4.0364447
# 0.000573302
# 0.00024915673
# 4.032696
# 0.0004978715
# 0.00013617947
# 4.0296717
# 0.00047151803
# 6.8903304e-05
# 4.0269814
# 0.0010820802
# 0.0005415684
# 4.025363
# 0.0005100671
# 0.00010706652
# 4.0232263
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3320212/2702430575.py in <module>
#       2     key, k1 = random.split(key)
#       3     loss_val, grads = loss_grad_fn(params, key)
# ----> 4     updates, opt_state = tx.update(grads, opt_state)
#       5     params = optax.apply_updates(params, updates)
#       6     if i % 99 == 0:
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/optax/_src/combine.py in update_fn(updates, state, params)
#      52     new_state = []
#      53     for s, fn in zip(state, update_fns):
# ---> 54       updates, new_s = fn(updates, s, params)
#      55       new_state.append(new_s)
#      56     return updates, tuple(new_state)
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/optax/_src/transform.py in update_fn(***failed resolving arguments***)
#     327     nu = _update_moment_per_elem_norm(updates, state.nu, b2, 2)
#     328     count_inc = numerics.safe_int32_increment(state.count)
# --> 329     mu_hat = utils.cast_tree(_bias_correction(mu, b1, count_inc), mu_dtype)
#     330     nu_hat = _bias_correction(nu, b2, count_inc)
#     331     updates = jax.tree_multimap(
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/optax/_src/transform.py in _bias_correction(moment, decay, count)
#     103 def _bias_correction(moment, decay, count):
#     104   """Perform bias correction. This becomes a no-op as count goes to infinity."""
# --> 105   bias_correction = 1 - decay**count
#     106   return jax.tree_map(lambda t: t / bias_correction.astype(t.dtype), moment)
#     107
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in deferring_binary_op(self, other)
#    6688     if not isinstance(other, _accepted_binop_types):
#    6689       return NotImplemented
# -> 6690     return binary_op(self, other)
#    6691   return deferring_binary_op
#    6692
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in <lambda>(x, y)
#    6692
#    6693 def _swap_args(f):
# -> 6694   return lambda x, y: f(y, x)
#    6695
#    6696 def _unimplemented_setitem(self, i, x):
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py in power(x1, x2)
#     933       pass
#     934     else:
# --> 935       return lax.integer_pow(x1, x2)
#     936   return _power(x1, x2)
#     937
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/lax/lax.py in integer_pow(x, y)
#     337 def integer_pow(x: Array, y: int) -> Array:
#     338   r"""Elementwise power: :math:`x^y`, where :math:`y` is a fixed integer."""
# --> 339   return integer_pow_p.bind(x, y=y)
#     340
#     341 def sqrt(x: Array) -> Array:
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/core.py in bind(self, *args, **params)
#     272     assert (not config.jax_enable_checks or
#     273             all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 274     return self.bind_with_trace(find_top_trace(args), args, params)
#     275
#     276   def bind_with_trace(self, trace, args, params):
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/core.py in bind_with_trace(self, trace, args, params)
#     275
#     276   def bind_with_trace(self, trace, args, params):
# --> 277     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     278     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     279
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/core.py in process_primitive(self, primitive, tracers, params)
#     591
#     592   def process_primitive(self, primitive, tracers, params):
# --> 593     return primitive.impl(*tracers, **params)
#     594
#     595   def process_call(self, primitive, f, tracers, params):
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/dispatch.py in apply_primitive(prim, *args, **params)
#      90 def apply_primitive(prim, *args, **params):
#      91   """Impl rule that compiles and runs a single primitive 'prim' using XLA."""
# ---> 92   compiled_fun = xla_primitive_callable(prim, *unsafe_map(arg_spec, args),
#      93                                         **params)
#      94   return compiled_fun(*args)
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/util.py in wrapper(*args, **kwargs)
#     200         return f(*args, **kwargs)
#     201       else:
# --> 202         return cached(config._trace_context(), *args, **kwargs)
#     203
#     204     wrapper.cache_clear = cached.cache_clear
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/util.py in cached(_, *args, **kwargs)
#     193     @functools.lru_cache(max_size)
#     194     def cached(_, *args, **kwargs):
# --> 195       return f(*args, **kwargs)
#     196
#     197     @functools.wraps(f)
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/dispatch.py in xla_primitive_callable(prim, *arg_specs, **params)
#     109     else:
#     110       return out,
# --> 111   compiled = _xla_callable_uncached(lu.wrap_init(prim_fun), device, None,
#     112                                     prim.name, donated_invars, *arg_specs)
#     113   if not prim.multiple_results:
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/dispatch.py in _xla_callable_uncached(fun, device, backend, name, donated_invars, *arg_specs)
#     167 def _xla_callable_uncached(fun: lu.WrappedFun, device, backend, name,
#     168                            donated_invars, *arg_specs):
# --> 169   return lower_xla_callable(fun, device, backend, name, donated_invars,
#     170                             *arg_specs).compile().unsafe_call
#     171
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/dispatch.py in compile(self)
#     524             **self.compile_args)
#     525       else:
# --> 526         self._executable = XlaCompiledComputation.from_xla_computation(
#     527             self.name, self._hlo, **self.compile_args)
#     528
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/dispatch.py in from_xla_computation(name, xla_computation, nreps, device, backend, tuple_args, in_avals, out_avals, kept_var_idx)
#     609     with log_elapsed_time(f"Finished XLA compilation of {name} "
#     610                           "in {elapsed_time} sec"):
# --> 611       compiled = compile_or_get_cached(backend, xla_computation, options)
#     612     buffer_counts = (None if len(out_avals) == 1 else
#     613                      [aval_to_num_buffers(aval) for aval in out_avals])
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/dispatch.py in compile_or_get_cached(backend, computation, compile_options)
#     578               else computation.as_hlo_text())
#     579     _dump_ir_to_file(module_name, ir_str)
# --> 580   return backend_compile(backend, computation, compile_options)
#     581
#     582
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     204   def wrapper(*args, **kwargs):
#     205     with TraceAnnotation(name, **decorator_kwargs):
# --> 206       return func(*args, **kwargs)
#     207     return wrapper
#     208   return wrapper
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/jax/_src/dispatch.py in backend_compile(backend, built_c, options)
#     533   # we use a separate function call to ensure that XLA compilation appears
#     534   # separately in Python profiling results
# --> 535   return backend.compile(built_c, compile_options=options)
#     536
#     537 # TODO(phawkins): update users.
#
# KeyboardInterrupt:

# %%
symb = get_symbolic_expr(params, funs, use_l0=True)[0]

# %%
symb
# Out:
# -0.465570261924418*(x1 - 0.000715150462958185)**2 + 1.73092937469482*sin(0.599526405334473*x0 - 0.00381057849153876) + 0.710983397051512

# %%
jit_apply = jax.jit(e.apply, static_argnames='deterministic')

# %%
jit_part = partial(jit_apply, params)
#jax.grad(jit_part)(x)

# %%
e.apply(params, rngs={'l0': k1}, method=e.l0_reg)
# Out:
# DeviceArray(508.99625, dtype=float32)

# %%
k1, _ = random.split(k1)
e.apply(params, x, deterministic=False, rngs={'l0': k1})
# Out:
# DeviceArray([[ 8.58321381e+00,  1.51409264e+01, -2.02603173e+00,
#                2.00298309e+01,  1.47476797e+01, -4.98244190e+00,
#                2.11784592e+01, -1.21116362e+01, -1.42601099e+01,
#               -4.60530281e+00],
#              [ 5.63098877e+02,  2.89830261e+02,  6.18977844e+02,
#                4.19883545e+02,  2.96393799e+02, -3.36902313e+02,
#                1.30909224e+01,  3.64777774e-01,  1.14763775e+01,
#                4.49562988e+01, -3.44426346e+01,  1.67161922e+01,
#               -2.10998058e+01],
#              [-4.34643412e+00,  4.46239889e-01,  2.02812299e-01,
#                4.48200077e-01, -5.77230394e-01, -4.78118038e+00,
#               -2.12557840e+00,  2.72447467e-01, -1.26302743e+00,
#               -1.56217468e+00],
#              [-2.52568836e+01, -8.18129539e+00, -3.64205217e+00,
#               -1.41927958e+00,  7.71645010e-01,  1.45304890e+01,
#                1.14133463e+01, -2.85707359e+01,  1.32542143e+01,
#                1.60419827e+01],
#              [-3.48058963e+00, -1.68934479e-01, -1.15981948e+00,
#               -2.67708331e-01,  6.06912374e+00, -4.40009594e+00,
#               -4.16104746e+00,  9.12585795e-01, -2.60698748e+00,
#                6.72912240e-01],
#              [-2.13652778e+00,  4.98958158e+00,  1.16645622e+00,
#               -2.38706827e+00,  3.68631065e-01,  1.95960546e+00,
#               -3.53142476e+00,  6.04384482e-01, -1.27376592e+00,
#                1.87722504e+00],
#              [ 7.20292332e+10,  2.04371942e+09,  3.99663104e+10,
#               -2.18973983e+10, -2.68541870e+10,  2.76677202e+10,
#                3.84084828e+10, -6.84919562e+10, -1.59884780e+10,
#                3.32235571e+10],
#              [ 1.03374219e+00, -4.26827812e+00,  2.83615923e+00,
#               -5.69018507e+00, -1.00460100e+01,  1.10322523e+00,
#                1.38703060e+01,  4.08678246e+00, -1.62304096e+01,
#               -1.34525423e+01],
#              [-8.82969177e+02,  7.60691833e+02, -9.31619812e+02,
#                6.23914429e+02,  1.71277237e+01,  6.52095459e+02,
#               -2.52798935e+02,  1.71816757e+02,  5.84385193e+02,
#                1.04789893e+03],
#              [-1.73120972e+03, -7.72709717e+02,  1.03068445e+03,
#               -9.11556213e+02, -1.00365625e+03, -3.01343670e+01,
#                6.08487854e+01, -2.36399194e+03, -7.63906494e+02,
#                4.26460541e+02],
#              [ 3.34452701e+00, -3.34341288e-01,  1.93894517e+00,
#                5.25085390e-01,  2.02780080e+00,  1.88019347e+00,
#                3.32984519e+00,  5.19319832e-01,  1.40002406e+00,
#               -1.23437572e+00],
#              [-2.19573164e+00, -4.81795430e-01, -3.61065239e-01,
#                2.12475717e-01, -5.52493930e-01,  7.84456491e-01,
#                4.71307546e-01, -4.30858284e-01,  5.64436495e-01,
#                1.41651940e+00],
#              [ 1.33870173e+00, -2.99959946e+00, -3.65632725e+00,
#                1.17492914e+00, -8.65467191e-01,  2.20895553e+00,
#                3.39501917e-01, -7.44102716e-01, -6.73600495e-01,
#               -2.57636070e+00]], dtype=float32)

# %%
#symb = get_symbolic_expr(unflatten(spec, x0), funs)
sy.lambdify("x0, x1, x2", symb[0])(x[:,0], x[:,1], x[:,2])
# Out:
# DeviceArray([ 0.57243985,  0.4264363 ,  0.20558922, ...,  0.4450177 ,
#              -0.22650672,  0.41479236], dtype=float32)

# %%
sy.lambdify(sy.symbols("x0, x1"), symb[1], "numpy")(x[:,0],x[:,1])
# Out:
# DeviceArray([ 0.29320884, 20.998196  ,  3.2638202 ], dtype=float32)
