# %%
from pmlb import fetch_data
from est import EQL, EQLTimed, EQLgd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV, PredefinedSplit

import sympy as sy
from sy_utils import *

# %%
from sklearn.metrics import r2_score

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
e = EQLgd(n_iter=10_000, drop_rate=.5, functions='id;mul;cos', reg=1e-3)
hp = {'reg': (1e-4, 1e-3, 1e-2, 5e-2),#(1, 1e-1, 1e-2, 5e-1, 5e-2, 5e-3),
      'n_layers': (1,2),
      'functions':('id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt',
                   #'id;mul;id;mul;id;mul'
                   #'id;mul;cos;sin;exp;square;sqrt'
                   #'id;mul;cos;square;cube;id;mul;cos;square;cube',
                   'id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id',
                  ),
     'do_bfgs': (True, False)}

# %%
cv.cv_results_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3500645/3049681812.py in <module>
# ----> 1 cv.cv_results_
#
# AttributeError: 'GridSearchCV' object has no attribute 'cv_results_'

# %%
r2_score(cv.best_estimator_.predict(data_X), data_y)
# Out:
# 0.8987522401693331

# %%
"""

1030_ERA
1028_SWD


589_fri_c2_1000_25
227_cpu_small
294_satellite_image
197_cpu_act


"""
# Out:
# '\n\n1030_ERA\n1028_SWD\n\n\n589_fri_c2_1000_25\n227_cpu_small\n294_satellite_image\n197_cpu_act\n\n\n'

# %%
data_X, data_y = fetch_data('589_fri_c2_1000_25', return_X_y=True, local_cache_dir='./pmlb_cache')

# %%
model(cv, pdf)
# Out:
# '[0.295*oz4 + 0.194*oz5 - 1.08*sin(1.22*oz1 + 1.57*oz2 - 0.443) - 1.29*sin(0.359*oz2 + 0.488*oz3 - 0.082*oz4 + 0.831) + 0.821]'

# %%
pdf = fetch_data('1030_ERA', local_cache_dir='./pmlb_cache')

# %%
split = PredefinedSplit([-1]*(data_X.shape[0]-1) + [0])

# %%
for (train, test) in split.split(data_X,data_y):
  print(len(train), len(test))
# Out:
# 999 1

# %%
cv = GridSearchCV(estimator=e,
                 param_grid=hp,
                 cv=2,#split,
                 #refit=True,
                 n_jobs=4,
                 verbose=5)

# %%
data_X.shape, data_y.shape
# Out:
# ((1000, 25), (1000,))

# %%
e = EQLgd(n_iter=10_000, drop_rate=.5, functions='id;mul;cos', reg=1e-3, random_state=42)

e.fit(data_X, data_y)
e.score(data_X, data_y)
e.get_eqn()
# Out:
# 0.09911464
# 1.5353136
# 0.098901995
# 0.09882203
# 0.098793976
# 0.09879119
# 0.09878078
# 0.09877351
# 0.09876725
# 0.09876475
# 0.09876268
# 0.09875722
# 0.098747805
# 0.098736934
# 0.098735124
# 0.09873139
# 0.0987308
# 0.09872997
# 0.09872823
# 0.09872574
# 0.09872254
# 0.098722
# 0.09872107
# 0.098721
# 0.09872097
# 0.09872094
# 0.09872092
# 0.098720856
# 0.09872076
# 0.0987207
# 0.09872079
# 0.098720685
# 0.09872067
# 0.09872067
# 0.09872066
# 0.09872064
# 0.098720655
# 0.098720655
# 0.09872064
# 0.09872064
# 0.09872064
# 0.09872064
# 0.09872064
# 0.09872064
# 0.09872064
# 0.09872064
# 0.09872064
# 0.09872064
# 0.09872064
# [-0.066*x0 + 0.03*x1 - 0.203*x2 + 0.386*x3 + 0.199*x4 - 0.327*(0.597*x0 + 0.532*x2 - 0.362)*(0.17*x0 - 0.698*x1 - 0.43*x2 + 0.025*x3 + 0.703) - 1.14*cos(1.17*x0 + 1.54*x1 - 2.0) - 0.223]

# %%
e = EQLgd(n_iter=10_000, drop_rate=.5, functions='id;mul;cos', reg=1e-3, do_bfgs=False, random_state=42)

e.fit(data_X, data_y)
e.score(data_X, data_y)
e.get_eqn()
# Out:
# [-0.072*x0 + 0.015*x1 - 0.18*x2 + 0.365*x3 + 0.194*x4 - 0.327*(0.582*x0 + 0.539*x2 - 0.375)*(0.166*x0 - 0.679*x1 - 0.459*x2 + 0.055*x3 + 0.702) - 1.14*cos(1.17*x0 + 1.54*x1 - 2.0) - 0.217]

# %%
e.score(data_X, data_y)
# Out:
# -1.8196865234069146

# %%
e.get_eqn()
# Out:
# [-0.423*x1 + 0.219*x3]

# %%
plt.plot(data_y)
plt.plot(cv.predict(data_X))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_1025338/3176453243.py in <module>
#       1 plt.plot(data_y)
# ----> 2 plt.plot(cv.predict(data_X))
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     118
#     119         # lambda, but not partial, allows help() to work with update_wrapper
# --> 120         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     121         # update the docstring of the returned function
#     122         update_wrapper(out, self.fn)
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in predict(self, X)
#     537
#     538         """
# --> 539         self._check_is_fitted('predict')
#     540         return self.best_estimator_.predict(X)
#     541
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _check_is_fitted(self, method_name)
#     521                                  % (type(self).__name__, method_name))
#     522         else:
# --> 523             check_is_fitted(self)
#     524
#     525     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1096
#    1097     if not attrs:
# -> 1098         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1099
#    1100
#
# NotFittedError: This GridSearchCV instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
cv.fit(data_X, data_y)
cv.score(data_X, data_y)
# Out:
# Fitting 2 folds for each of 32 candidates, totalling 64 fits
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 0.08805301
# 1.6556439
# 0.09011435
# 0.10778215
# 0.08641072
# 0.10781833
# 0.08283468
# 0.095520906
# 0.09537786
# 0.30574453
# 0.08887619
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=1, reg=0.0001;, score=0.882 total time=  38.3s
# 0.43460453
# 0.48474583
# 0.8775681
# 0.29924646
# 0.34024084
# 0.5703776
# 0.31846792
# 0.36970773
# 0.3287716
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.001;, score=0.888 total time= 2.3min
# 0.6511826
# 1.2264744
# 0.67089665
# 0.84621066
# 0.64995784
# 0.71941954
# 0.73625195
# 0.6717927
# 0.6341212
# 0.6436201
# 0.6801131
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.01;, score=0.878 total time=  14.3s
# 1.3932962
# 1.4644569
# 1.5141126
# 1.4866179
# 1.3044553
# 1.3359559
# 1.4117504
# 1.4186127
# 1.4412766
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.05;, score=0.941 total time=  13.2s
# 0.39656055
# 0.25672418
# 0.25225934
# 0.56819266
# 0.2672895
# 0.17735077
# 0.15827058
# 0.18527864
# 0.20562753
# 0.33572298
# 0.1509958
# 4.6732645
# 5.088381
# 0.58752596
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.0001;, score=0.841 total time=  40.5s
# 0.50957525
# 3.9004471
# 0.4235075
# 0.37312654
# 0.3885532
# 0.4025704
# 0.37754178
# 0.37150323
# 0.91915274
# 0.74441224
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.001;, score=0.831 total time=  28.9s
# 1.3154244
# 2.1514223
# 1.4055878
# 1.942643
# 1.3446361
# 1.2565219
# 1.351583
# 1.3121371
# 1.2945297
# 1.2928641
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.01;, score=0.777 total time=  11.4s
# 5.694287
# 31.168125
# 5.6320643
# 5.6962647
# 5.636556
# 5.6365232
# 5.6627564
# 5.6516137
# 5.6346474
# 5.6372776
# 5.6375237
# 5.6374774
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.05;, score=-2.285 total time=  10.1s
# 1.6162153
# 1.3499991
# 2.9851155
# 1.4073926
# 7.0960765
# 1.6543624
# 1.5135903
# 3.5586388
# 17.72236
# 10.842624
# 17.794538
# 1.3012011
# 13.611612
# 20484.99
# 2.2526324
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=2, reg=0.0001;, score=-0.904 total time=218.4min
# 10.035693
# 11.880116
# 20930.18
# 8.100586
# 7.7090096
# 42.580044
# 2174.4075
# 20643.986
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=2, reg=0.01;, score=-0.094 total time=85.6min
# /home/alessandro/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:688: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 0.14783417
# 1.808549
# 0.10509881
# 0.09808723
# 0.09893038
# 0.119698904
# 0.11185933
# 0.097607404
# 0.13614467
# 0.18014818
# 0.092954434
# 0.10075681
# 0.14414515
# 0.10980021
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=1, reg=0.0001;, score=0.846 total time=  40.1s
# 0.27763385
# 1.7018253
# 0.3814779
# 0.3009536
# 0.27207953
# 0.30755076
# 0.3506127
# 0.33825207
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.001;, score=0.947 total time= 2.3min
# 0.77255756
# 1.1257178
# 1.0499325
# 0.6372612
# 0.7406879
# 0.5783167
# 0.5844928
# 0.62252647
# 0.64523005
# 0.63712317
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.01;, score=0.845 total time=  13.8s
# 1.2302731
# 2.228288
# 1.225936
# 1.2213329
# 1.2267025
# 1.2265794
# 1.2242819
# 1.2243792
# 1.2243782
# 1.2243248
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.05;, score=0.557 total time=  13.0s
# 0.161508
# 0.45377305
# 0.15262471
# 0.16675913
# 0.21094058
# 0.47639683
# 0.25679946
# 12.456565
# 0.18923411
# 0.55350053
# 0.19629073
# 0.18340686
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.0001;, score=0.789 total time=  40.7s
# 0.46484563
# 3889.8474
# 2.9814622
# 0.47702184
# 0.48452026
# 0.68537444
# 0.48657805
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.001;, score=0.845 total time=  36.6s
# 1.2701488
# 1.7966541
# 9.95874
# 1.2540871
# 1.2424539
# 1.2803501
# 1.2373874
# 1.4123185
# 1.7544197
# 1.2184312
# 1.3227538
# 1.2302246
# 1.2158341
# 1.2240511
# 1.2372639
# 1.267912
# 1.226886
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.01;, score=0.808 total time=  10.9s
# 5.665851
# 5.1269164
# 5.2567315
# 5.370867
# 5.124266
# 6.934197
# 5.18003
# 5.132554
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.05;, score=0.393 total time=  11.0s
# 6.314962
# 1.6106952
# 22.169796
# 12.830056
# 14.657611
# 13.740275
# 64.46864
# 59.918007
# 366.434
# 5.980212
# 19.954775
# 2.7205844
# 69.64644
# 3.5029616
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=2, reg=0.0001;, score=-0.030 total time=219.9min
# 564.1379
# 19.631302
# 220.6701
# 20.099703
# 194.91148
# 746.2646
# 127.405235
# 138.19005
# 8.364803
# 2669.479
# 55.237984
# 7.143314
# 7.7382326
# 6.9252305
# 11.700858
# 12279.476
# 6.7091413
# 7.1933947
# 6.4311132
# 38.004112
# 2032137.1
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=2, reg=0.01;, score=-0.003 total time=86.9min
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 0.17032848
# 1.830218
# 0.23536935
# 0.18760724
# 0.16089948
# 0.17775007
# 0.17053752
# 0.27409515
# 0.2078586
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=1, reg=0.001;, score=0.905 total time=  21.7s
# 0.37759262
# 1.5619949
# 0.552456
# 0.37579572
# 0.37574002
# 0.37956285
# 0.39395362
# 0.39979392
# 0.47433108
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=1, reg=0.01;, score=0.976 total time=   7.0s
# 0.8712813
# 1.3162738
# 0.87066877
# 0.8701817
# 0.8694034
# 1.4048673
# 0.86908764
# 0.8690397
# 0.8661534
# 0.8647483
# 0.850798
# 0.8405188
# 0.82692194
# 0.8173304
# 0.78428245
# 0.85694987
# 0.7492089
# 0.6873878
# 0.61840564
# 0.6980968
# 0.8294807
# 0.5922648
# 0.5338391
# 0.5189318
# 0.49314043
# 0.92242175
# 0.52297246
# 0.507926
# 0.5079269
# 0.6586853
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=1, reg=0.05;, score=0.811 total time=   7.7s
# 0.36587676
# 0.97446644
# 0.12769483
# 0.18252963
# 0.14254901
# 0.16900644
# 0.25910628
# 0.19335994
# 0.2892597
# [CV 2/2] END do_bfgs=True, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.0001;, score=0.871 total time=208.8min
# 1409.968
# 5.802008
# 6.641494
# 16.7071
# 4.8748775
# 19.374058
# 60.52892
# 2.1118965
# 106.122925
# 9.226825
# 3793.8728
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=2, reg=0.001;, score=-0.020 total time=86.8min
# 180.27411
# 488.33517
# 193.95587
# 37.64797
# 259.46796
# 371.22314
# 47.669014
# 75.90071
# 16909.145
# 37.541885
# 27.42934
# 28.796387
# 363.76282
# 36.016697
# [CV 1/2] END do_bfgs=True, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=2, reg=0.05;, score=-0.353 total time=66.6min
# [CV 1/2] END do_bfgs=False, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.01;, score=0.844 total time=  13.4s
# [CV 2/2] END do_bfgs=False, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.01;, score=0.971 total time=  13.2s
# [CV 1/2] END do_bfgs=False, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.05;, score=0.279 total time=  12.7s
# [CV 2/2] END do_bfgs=False, functions=id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt, n_layers=2, reg=0.05;, score=0.988 total time=  12.5s
# [CV 1/2] END do_bfgs=False, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.0001;, score=0.865 total time=  34.7s
# [CV 2/2] END do_bfgs=False, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.0001;, score=-0.087 total time=  33.8s
# [CV 1/2] END do_bfgs=False, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.01;, score=0.548 total time=  10.9s
# [CV 1/2] END do_bfgs=False, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.05;, score=-8.569 total time=  10.6s
# [CV 2/2] END do_bfgs=False, functions=id;mul;cos;div;sqrt;cos;sin;div;mul;mul;cos;id, n_layers=1, reg=0.05;, score=0.137 total time=  10.4s
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     438
# --> 439                 self._condition.wait(timeout)
#     440
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3500645/771402039.py in <module>
# ----> 1 cv.fit(data_X, data_y)
#       2 cv.score(data_X, data_y)
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1294     def _run_search(self, evaluate_candidates):
#    1295         """Search all candidates in param_grid"""
# -> 1296         evaluate_candidates(ParameterGrid(self.param_grid))
#    1297
#    1298
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     953                     # scheduling.
#     954                     ensure_ready = self._managed_backend
# --> 955                     backend.abort_everything(ensure_ready=ensure_ready)
#     956                 raise
#     957
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/joblib/_parallel_backends.py in abort_everything(self, ensure_ready)
#     559         """Shutdown the workers and restart a new one with the same parameters
#     560         """
# --> 561         self._workers.terminate(kill_workers=True)
#     562         self._workers = None
#     563
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/joblib/executor.py in terminate(self, kill_workers)
#      72
#      73     def terminate(self, kill_workers=False):
# ---> 74         self.shutdown(kill_workers=kill_workers)
#      75         if kill_workers:
#      76             # When workers are killed in such a brutal manner, they cannot
#
# ~/code/NeuralSymbolicRegressionThatScales/env/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py in shutdown(self, wait, kill_workers)
#    1169
#    1170         if executor_manager_thread is not None and wait:
# -> 1171             executor_manager_thread.join()
#    1172
#    1173         # To reduce the risk of opening too many files, remove references to
#
# /usr/lib/python3.8/threading.py in join(self, timeout)
#    1009
#    1010         if timeout is None:
# -> 1011             self._wait_for_tstate_lock()
#    1012         else:
#    1013             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.8/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1025         if lock is None:  # already determined that the C code is done
#    1026             assert self._is_stopped
# -> 1027         elif lock.acquire(block, timeout):
#    1028             lock.release()
#    1029             self._stop()
#
# KeyboardInterrupt:

# %%
cv.best_params_
# Out:
# {'functions': 'id;mul;cos;sin;exp;square;sqrt;id;mul;cos;sin;exp;square;sqrt',
#  'n_layers': 2,
#  'reg': 0.0001}

# %%
cv.predict(data_X)
# Out:
# DeviceArray([[nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan],
#              [nan]], dtype=float32)

# %%
str(cv.best_estimator_.get_eqn())
# Out:
# '[nan]'

# %%
def sim(c):
    return round(-0.3*math.log(c / 120, 5), 1)
plt.plot([sim(x) for x in np.arange(5, 200)])

# %%
sim(5)
# Out:
# 0.99

# %%
def model(est, X=None):
    mapping = {'x'+str(i):k for i,k in enumerate(X.columns)}
    model_str = str(est.best_estimator_.get_eqn())
    for k,v in mapping.items():
        model_str = model_str.replace(k,v)
    return model_str
